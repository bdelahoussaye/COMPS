# %%
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports and toolboxes needed for workflow
# System imports
import os
import sys

# Mathematical imports
import numpy as np
import math

# To make this notebook's output stable across runs
np.random.seed(42)

# Data structure imports
import csv
import glob
from collections import Counter # https://docs.python.org/2/library/collections.html
import re
import pandas as pd
from pandas import set_option
set_option('display.max_columns',400)


# Machine Learning and Statistical imports
import scipy
from sklearn.cluster import KMeans


# Computer Vision imports
import cv2
import PIL
from PIL import Image
from skimage.color import rgb2lab, deltaE_cie76


# Visualization imports
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from matplotlib import image as img
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rcParams['figure.figsize'] = (100,100)

import seaborn as sns

from bokeh.io import push_notebook, show, output_notebook
from bokeh.models import ColumnDataSource, ColorBar
from bokeh.palettes import Spectral6
from bokeh.transform import linear_cmap
from bokeh.plotting import figure
output_notebook()

# Where to save the figures
PROJECT_ROOT_DIR = "."
IMAGE_ID = "EDA_Images"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "Images", IMAGE_ID)
os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)


# Ignore useless warnings 
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore', DeprecationWarning)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
# %%time
mydir='/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/'

def createFileList(myDir, format='.xlsx'):
    filelist = []
    print('\nCurrent Working Directory:\n', myDir, end='\n')
    
    for root, dirs, files in os.walk(myDir, topdown=False):
        for file in files:
            if file.endswith(format):
                fullName = os.path.join(root, file)
                filelist.append(fullName)
        print('\nList of SIC Data:\n', filelist, end='\n')
    return filelist

filelist = createFileList(mydir)
# Out:
# Current Working Directory:
#  /Users/peterflaming/Documents/GitHub/COMPS/Raw Data/
#
# List of SIC Data:
#  ['/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_6_advancesearch15668837465e1a60171bf79.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_0_advancesearch16784737975e1a5b2c8cbeb.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/~$SIC_0_advancesearch16784737975e1a5b2c8cbeb.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_3_advancesearch16953607965e1a5cf27817a.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_1_advancesearch12906045365e1a5bb125324.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_5_advancesearch8208422685e1a5e4281b83.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_8_advancesearch19810233385e1a613f38c47.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_4_advancesearch14170920915e1a5dbd6cddc.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_9_advancesearch6238149715e1a61b38247d.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_2_advancesearch15616274825e1a5c405bce4.xlsx', '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_7_advancesearch5468595875e1a60a2066b1.xlsx']
# CPU times: user 694 µs, sys: 778 µs, total: 1.47 ms
# Wall time: 839 µs

# %%
# %%time
# Sort and view the list of images
filelist.sort()
filelist
# Out:
# CPU times: user 16 µs, sys: 0 ns, total: 16 µs
# Wall time: 20 µs
# ['/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_0_advancesearch16784737975e1a5b2c8cbeb.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_1_advancesearch12906045365e1a5bb125324.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_2_advancesearch15616274825e1a5c405bce4.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_3_advancesearch16953607965e1a5cf27817a.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_4_advancesearch14170920915e1a5dbd6cddc.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_5_advancesearch8208422685e1a5e4281b83.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_6_advancesearch15668837465e1a60171bf79.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_7_advancesearch5468595875e1a60a2066b1.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_8_advancesearch19810233385e1a613f38c47.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/SIC_9_advancesearch6238149715e1a61b38247d.xlsx',
#  '/Users/peterflaming/Documents/GitHub/COMPS/Raw Data/~$SIC_0_advancesearch16784737975e1a5b2c8cbeb.xlsx']

# %%
# %%time
sic0 = pd.concat(pd.read_excel(filelist[0], sheet_name=None), ignore_index=True)
sic1 = pd.concat(pd.read_excel(filelist[1], sheet_name=None), ignore_index=True)
sic2 = pd.concat(pd.read_excel(filelist[2], sheet_name=None), ignore_index=True)
sic3 = pd.concat(pd.read_excel(filelist[3], sheet_name=None), ignore_index=True)
sic4 = pd.concat(pd.read_excel(filelist[4], sheet_name=None), ignore_index=True)
sic5 = pd.concat(pd.read_excel(filelist[5], sheet_name=None), ignore_index=True)
sic6 = pd.concat(pd.read_excel(filelist[6], sheet_name=None), ignore_index=True)
sic7 = pd.concat(pd.read_excel(filelist[7], sheet_name=None), ignore_index=True)
sic8 = pd.concat(pd.read_excel(filelist[8], sheet_name=None), ignore_index=True)
sic9 = pd.concat(pd.read_excel(filelist[9], sheet_name=None), ignore_index=True)
# Out:
# CPU times: user 20.7 s, sys: 92.3 ms, total: 20.8 s
# Wall time: 20.8 s

# %%
sic0
# Out:
#                       Auditors                         Company Name  \
# 0                          NaN                        CORTEVA, INC.
# 1   PricewaterhouseCoopers LLP  CHIQUITA BRANDS INTERNATIONAL, INC.
# 2                          NaN                    THE ANDERSONS INC
# 3                          NaN            BRIGHTVIEW HOLDINGS, INC.
# 4            Ernst & Young LLP                CAL-MAINE FOODS, INC.
# ..                         ...                                  ...
# 79                         NaN   TWO RIVERS WATER & FARMING COMPANY
# 80                         NaN                      AMERICANN, INC.
# 81                         NaN         U.S. TIMBERLANDS COMPANY, LP
# 82                         NaN        VELT INTERNATIONAL GROUP INC.
# 83                         NaN               AGRITEK HOLDINGS, INC.
#
#    Company Type D-U-N-S@ Number Domestic Parent Duns No  \
# 0        Public     11-681-4324             11-681-4324
# 1        Public     05-154-1597             05-154-1597
# 2        Public     19-699-1731             19-699-1731
# 3        Public     07-941-1785             07-940-7937
# 4        Public     05-064-3436             05-064-3436
# ..          ...             ...                     ...
# 79          NaN     14-023-5396                     NaN
# 80          NaN     96-756-0470                     NaN
# 81          NaN     36-155-0713                     NaN
# 82          NaN     07-848-4195                     NaN
# 83          NaN     01-881-0767                     NaN
#
#          Domestic Parent Name Employee All Sites Employee this Site  \
# 0               CORTEVA, INC.             44,000                 28
# 1   CHIQUITA HOLDINGS LIMITED             20,000              1,000
# 2           THE ANDERSONS INC              1,858                150
# 3     BRIGHTVIEW PARENT, L.P.             19,000                 31
# 4       CAL-MAINE FOODS, INC.              3,573                422
# ..                        ...                ...                ...
# 79                        NaN                NaN                NaN
# 80                        NaN                NaN                NaN
# 81                        NaN                NaN                NaN
# 82                        NaN                NaN                NaN
# 83                        NaN                NaN                NaN
#
#    Employees Total (Year 1)  Employer ID Number (EIN) Facility Size  Fax No  \
# 0                    21,900               824979096.0             0     NaN
# 1                    20,000                41923360.0             0     NaN
# 2                     3,498               341562374.0       245,000     NaN
# 3                    19,000                       NaN             0     NaN
# 4                     3,573               640500378.0             0     NaN
# ..                      ...                       ...           ...     ...
# 79                      NaN                       NaN           NaN     NaN
# 80                      NaN                       NaN           NaN     NaN
# 81                      NaN                       NaN           NaN     NaN
# 82                      NaN                       NaN           NaN     NaN
# 83                      NaN                       NaN           NaN     NaN
#
#     Former Name Global Duns No                Global Name  \
# 0           NaN    11-681-4324              CORTEVA, INC.
# 1           NaN    22-031-2707  CHIQUITA HOLDINGS LIMITED
# 2           NaN    19-699-1731          THE ANDERSONS INC
# 3           NaN    07-940-7937    BRIGHTVIEW PARENT, L.P.
# 4           NaN    05-064-3436      CAL-MAINE FOODS, INC.
# ..          ...            ...                        ...
# 79          NaN            NaN                        NaN
# 80          NaN            NaN                        NaN
# 81          NaN            NaN                        NaN
# 82          NaN            NaN                        NaN
# 83          NaN            NaN                        NaN
#
#    Immediate Parent Duns No      Immediate Parent Name Import/Export  \
# 0               11-681-4324              CORTEVA, INC.           NaN
# 1               22-031-2707  CHIQUITA HOLDINGS LIMITED          Both
# 2               19-699-1731          THE ANDERSONS INC           NaN
# 3               07-940-7937    BRIGHTVIEW PARENT, L.P.           NaN
# 4               05-064-3436      CAL-MAINE FOODS, INC.           NaN
# ..                      ...                        ...           ...
# 79                      NaN                        NaN           NaN
# 80                      NaN                        NaN           NaN
# 81                      NaN                        NaN           NaN
# 82                      NaN                        NaN           NaN
# 83                      NaN                        NaN           NaN
#
#      Latitude                           Line of Business Location Type  \
# 0   39.752410          CROP PLANTING AND PROTECTION, NSK  Headquarters
# 1   26.062705             FRUITS AND TREE NUTS, NEC, NSK  Headquarters
# 2   41.582325  CROP PREPARATION SERVICES FOR MARKET, NSK  Headquarters
# 3   40.147526     LANDSCAPE COUNSELING AND PLANNING, NSK  Headquarters
# 4   32.325416                          CHICKEN EGGS, NSK  Headquarters
# ..        ...                                        ...           ...
# 79        NaN                                        NaN           NaN
# 80        NaN                                        NaN           NaN
# 81        NaN                                        NaN           NaN
# 82        NaN                                        NaN           NaN
# 83        NaN                                        NaN           NaN
#
#     Longtitude Mailing Address Mailing City Mailing Country Mailing County  \
# 0   -75.609399             NaN          NaN             NaN            NaN
# 1   -80.161274             NaN          NaN             NaN            NaN
# 2   -83.696756    P.O. BOX 119       MAUMEE             USA          LUCAS
# 3   -75.288898             NaN          NaN             NaN            NaN
# 4   -90.223854   P.O. BOX 2960      JACKSON             USA          HINDS
# ..         ...             ...          ...             ...            ...
# 79         NaN             NaN          NaN             NaN            NaN
# 80         NaN             NaN          NaN             NaN            NaN
# 81         NaN             NaN          NaN             NaN            NaN
# 82         NaN             NaN          NaN             NaN            NaN
# 83         NaN             NaN          NaN             NaN            NaN
#
#    Mailing State  Mailing Zipcode Manufacturing Indicator  \
# 0            NaN              NaN        Non Manufacturer
# 1            NaN              NaN        Non Manufacturer
# 2           OHIO      435370119.0        Non Manufacturer
# 3            NaN              NaN            Manufacturer
# 4    MISSISSIPPI      392072960.0            Manufacturer
# ..           ...              ...                     ...
# 79           NaN              NaN                     NaN
# 80           NaN              NaN                     NaN
# 81           NaN              NaN                     NaN
# 82           NaN              NaN                     NaN
# 83           NaN              NaN                     NaN
#
#    Marketing Prescreen Ranking Marketing Prescreen Score  \
# 0       1 - Most likely to pay                       Low
# 1      5 - Least Likely to pay                      High
# 2            2 - Likely to pay                       Low
# 3       1 - Most likely to pay                       Low
# 4       4 - Less likely to pay                       Low
# ..                         ...                       ...
# 79                         NaN                       NaN
# 80                         NaN                       NaN
# 81                         NaN                       NaN
# 82                         NaN                       NaN
# 83                         NaN                       NaN
#
#    Minority Owned Indicator Owns/Rents        Phone No  \
# 0                        No        NaN  (302) 485-3000
# 1                        No       Rent  (954) 924-5700
# 2                        No       Rent  (419) 893-5050
# 3                        No       Rent  (484) 567-7204
# 4                        No        NaN  (601) 948-6813
# ..                      ...        ...             ...
# 79                      NaN        NaN             NaN
# 80                      NaN        NaN             NaN
# 81                      NaN        NaN             NaN
# 82                      NaN        NaN             NaN
# 83                      NaN        NaN             NaN
#
#              Physical Address Physical City Physical Country Physical County  \
# 0      974 CENTRE RD BLDG 735    WILMINGTON              USA      NEW CASTLE
# 1    1855 GRIFFIN RD STE C436         DANIA              USA         BROWARD
# 2        1947 BRIARFIELD BLVD        MAUMEE              USA           LUCAS
# 3        980 JOLLY RD STE 300     BLUE BELL              USA      MONTGOMERY
# 4   3320 W WOODROW WILSON AVE       JACKSON              USA           HINDS
# ..                        ...           ...              ...             ...
# 79                        NaN           NaN              NaN             NaN
# 80                        NaN           NaN              NaN             NaN
# 81                        NaN           NaN              NaN             NaN
# 82                        NaN           NaN              NaN             NaN
# 83                        NaN           NaN              NaN             NaN
#
#    Physical State  Physical Zipcode  Primary SIC Code  \
# 0        DELAWARE       198051269.0         7210300.0
# 1         FLORIDA       330042275.0         1799902.0
# 2            OHIO       435371690.0         7230000.0
# 3    PENNSYLVANIA       194221904.0         7810200.0
# 4     MISSISSIPPI       392093409.0         2520000.0
# ..            ...               ...               ...
# 79            NaN               NaN               NaN
# 80            NaN               NaN               NaN
# 81            NaN               NaN               NaN
# 82            NaN               NaN               NaN
# 83            NaN               NaN               NaN
#
#                    Rank Type            Sales  Sales (Year 1)  \
# 0                        NaN  $30,671,050,478  $3,125,084,910
# 1                        NaN   $3,399,246,400  $3,090,224,000
# 2                        NaN   $3,045,382,000  $3,045,382,000
# 3                        NaN   $2,353,603,000  $2,353,603,000
# 4   Russell 2000 (June 2016)   $1,361,188,000  $1,502,932,000
# ..                       ...              ...             ...
# 79                       NaN              NaN             NaN
# 80                       NaN              NaN             NaN
# 81                       NaN              NaN             NaN
# 82                       NaN              NaN             NaN
# 83                       NaN              NaN             NaN
#
#    Subsidiary Status          Trade Style      Web Address (URL)  \
# 0     Non-Subsidiary  CORTEVA AGRISCIENCE        WWW.CORTEVA.COM
# 1         Subsidiary             CHIQUITA       WWW.CHIQUITA.COM
# 2     Non-Subsidiary                  NaN   WWW.ANDERSONSINC.COM
# 3         Subsidiary                  NaN     WWW.BRIGHTVIEW.COM
# 4     Non-Subsidiary                  NaN  WWW.CALMAINEFOODS.COM
# ..               ...                  ...                    ...
# 79               NaN                  NaN                    NaN
# 80               NaN                  NaN                    NaN
# 81               NaN                  NaN                    NaN
# 82               NaN                  NaN                    NaN
# 83               NaN                  NaN                    NaN
#
#     Year of Founding Year1 Calculated Tax Rate % Year1 Capital Expenditures  \
# 0             2018.0                         NaN                        NaN
# 1             1899.0                         NaN                        NaN
# 2             1947.0                         NaN                        NaN
# 3             2013.0                         NaN                        NaN
# 4             1957.0                         NaN                        NaN
# ..               ...                         ...                        ...
# 79               NaN                           0                        NaN
# 80               NaN                       EBT<0                    702,702
# 81               NaN                         NaN                    160,000
# 82               NaN                       EBT<0                      7,378
# 83               NaN                       EBT<0                     34,323
#
#    Year1 Cash & Cash Equivalents, Beginning of Year  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 79                                           14,000
# 80                                            1,627
# 81                                        1,070,000
# 82                                           50,515
# 83                                          304,889
#
#    Year1 Cash & Cash Equivalents, End of Year  Year1 Cash Flow per Share  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# ..                                        ...                        ...
# 79                                      6,000                      -0.03
# 80                                  4,016,949                      -0.12
# 81                                    965,000                       0.25
# 82                                        127                      -0.09
# 83                                     77,016                      -0.31
#
#    Year1 Cash from Financing Year1 Cash from Investing  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 79                 1,065,000                   -13,000
# 80                 7,131,345                  -712,702
# 81                       NaN                -3,338,000
# 82                   134,772                    -7,378
# 83                 1,141,942                  -109,323
#
#    Year1 Cash from Operations Year1 Current Assets Year1 Current Liabilities  \
# 0                         NaN                  NaN                       NaN
# 1                         NaN                  NaN                       NaN
# 2                         NaN                  NaN                       NaN
# 3                         NaN                  NaN                       NaN
# 4                         NaN                  NaN                       NaN
# ..                        ...                  ...                       ...
# 79                 -1,060,000               64,000                20,092,000
# 80                 -2,403,321            4,082,378                   844,826
# 81                  3,233,000            3,885,000                 5,444,000
# 82                   -177,782                  127                   227,693
# 83                 -1,260,492              115,709                 3,519,714
#
#     Year1 Current Ratio Year1 EBITDA Year1 EBITDA Margin %  \
# 0                   NaN          NaN                   NaN
# 1                   NaN          NaN                   NaN
# 2                   NaN          NaN                   NaN
# 3                   NaN          NaN                   NaN
# 4                   NaN          NaN                   NaN
# ..                  ...          ...                   ...
# 79                 0.00    7,228,000             10,951.52
# 80                 4.83      228,298                   NaN
# 81                 0.71   24,293,000                  49.1
# 82                 0.00     -184,545                -800.7
# 83                 0.03    1,350,133             40,435.25
#
#     Year1 EPS - Net Income - Diluted  Year1 EPS from Continuing Operations  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ..                               ...                                   ...
# 79                              0.07                                  0.12
# 80                             -0.22                                 -0.22
# 81                             -6.74                                   NaN
# 82                             -0.10                                 -0.10
# 83                             -0.34                                 -0.34
#
#     Year1 Earnings per Share - Basic  Year1 Free Cash Flow per Share  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 79                              0.08                           -0.03
# 80                             -0.22                           -0.15
# 81                             -6.74                            0.24
# 82                             -0.10                           -0.10
# 83                             -0.34                           -0.31
#
#    Year1 Gross Margin Year1 Long Term Debt Year1 Net Assets per Share  \
# 0                 NaN                  NaN                        NaN
# 1                 NaN                  NaN                        NaN
# 2                 NaN                  NaN                        NaN
# 3                 NaN                  NaN                        NaN
# 4                 NaN                  NaN                        NaN
# ..                ...                  ...                        ...
# 79                100            1,173,000                      -0.28
# 80                NaN            1,782,319                       0.31
# 81              -6.76          225,000,000                      -1.39
# 82                100                  NaN                      -0.12
# 83          -1,731.93                  NaN                      -0.52
#
#    Year1 Net Current Assets as % of Total Assets Year1 Net Income  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
# 3                                            NaN              NaN
# 4                                            NaN              NaN
# ..                                           ...              ...
# 79                                        -65.33        3,722,000
# 80                                         34.23       -4,432,716
# 81                                         -0.74      -43,821,000
# 82                                     -3,538.58         -185,619
# 83                                       -598.07       -1,412,278
#
#    Year1 Operating Income Year1 Operating Margin  Year1 Price/Book (TTM)  \
# 0                     NaN                    NaN                     NaN
# 1                     NaN                    NaN                     NaN
# 2                     NaN                    NaN                     NaN
# 3                     NaN                    NaN                     NaN
# 4                     NaN                    NaN                     NaN
# ..                    ...                    ...                     ...
# 79             -4,795,000              -7,265.15                     NaN
# 80                    NaN                    NaN                    9.84
# 81            -10,861,000                 -21.95                     NaN
# 82               -146,509                -635.67                     NaN
# 83             -1,354,883             -40,577.51                     NaN
#
#     Year1 Price/Cash Flow(TTM)  Year1 Price/Earnings (TTM)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 79                         NaN                        2.13
# 80                         NaN                         NaN
# 81                       10.98                         NaN
# 82                         NaN                         NaN
# 83                         NaN                         NaN
#
#    Year1 Profit Margin (TTM)  Year1 Quick Ratio Year1 Revenue per Share  \
# 0                        NaN                NaN                     NaN
# 1                        NaN                NaN                     NaN
# 2                        NaN                NaN                     NaN
# 3                        NaN                NaN                     NaN
# 4                        NaN                NaN                     NaN
# ..                       ...                ...                     ...
# 79                  5,639.39                NaN                       0
# 80                       NaN                NaN                     NaN
# 81                    -88.57               0.65                    3.85
# 82                   -805.36                NaN                    0.01
# 83                -42,296.44               0.02                       0
#
#     Year1 Revenue to Assets Year1 Share Outstanding  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 79                     0.00              45,574,458
# 80                      NaN              22,106,706
# 81                     0.23              13,930,137
# 82                     3.58               1,886,622
# 83                     0.01               5,628,475
#
#    Year1 Stockholders' Equity Year1 Total Assets Year1 Total Assets per Share  \
# 0                         NaN                NaN                          NaN
# 1                         NaN                NaN                          NaN
# 2                         NaN                NaN                          NaN
# 3                         NaN                NaN                          NaN
# 4                         NaN                NaN                          NaN
# ..                        ...                ...                          ...
# 79                -12,970,000         30,659,000                         0.67
# 80                  6,830,276          9,457,421                         0.43
# 81                          0        211,041,000                        15.15
# 82                   -221,262              6,431                            0
# 83                 -2,950,547            569,167                          0.1
#
#    Year1 Total Liabilities Year1 Total Revenue  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ..                     ...                 ...
# 79              43,629,000              66,000
# 80               2,627,145                 NaN
# 81             230,444,000          49,474,000
# 82                 227,693              23,048
# 83               3,519,714               3,339
#
#    Year1 Weighted Average Shares Outstanding - Basic  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 79                                        35,139,000
# 80                                        20,066,824
# 81                                        12,859,607
# 82                                         1,886,622
# 83                                         4,124,863
#
#    Year1 Weighted Average Shares Outstanding - Diluted  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                         37,408,000
# 80                                         20,066,824
# 81                                         12,859,607
# 82                                          1,886,622
# 83                                          4,124,863
#
#    Year2 Calculated Tax Rate % Year2 Capital Expenditures  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 79                       EBT<0                 -1,215,000
# 80                       EBT<0                    500,720
# 81                         NaN                        NaN
# 82                       EBT<0                        NaN
# 83                       EBT<0                    187,651
#
#    Year2 Cash & Cash Equivalents, Beginning of Year  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 79                                          150,000
# 80                                               24
# 81                                        3,168,000
# 82                                          114,508
# 83                                           67,260
#
#    Year2 Cash & Cash Equivalents, End of Year  Year2 Cash Flow per Share  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# ..                                        ...                        ...
# 79                                     14,000                      -0.09
# 80                                      1,627                      -0.09
# 81                                  1,070,000                       0.71
# 82                                     50,515                      -0.06
# 83                                    304,889                      -0.46
#
#    Year2 Cash from Financing Year2 Cash from Investing  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 79                 1,547,000                 1,215,000
# 80                 2,070,527                  -320,976
# 81                -6,561,000                -4,711,000
# 82                    53,593                     2,994
# 83                 1,864,115                  -397,651
#
#    Year2 Cash from Operations Year2 Current Assets Year2 Current Liabilities  \
# 0                         NaN                  NaN                       NaN
# 1                         NaN                  NaN                       NaN
# 2                         NaN                  NaN                       NaN
# 3                         NaN                  NaN                       NaN
# 4                         NaN                  NaN                       NaN
# ..                        ...                  ...                       ...
# 79                 -2,898,000               70,000                24,777,000
# 80                 -1,747,948               64,586                 1,800,575
# 81                  9,174,000            3,039,000                 4,706,000
# 82                   -120,580               50,515                    86,158
# 83                 -1,228,835              405,251                 7,077,944
#
#     Year2 Current Ratio Year2 EBITDA Year2 EBITDA Margin %  \
# 0                   NaN          NaN                   NaN
# 1                   NaN          NaN                   NaN
# 2                   NaN          NaN                   NaN
# 3                   NaN          NaN                   NaN
# 4                   NaN          NaN                   NaN
# ..                  ...          ...                   ...
# 79                 0.00   -8,616,000             -1,245.09
# 80                 0.04   -2,373,647             -5,934.12
# 81                 0.65   30,069,000                 55.11
# 82                 0.59     -379,656                -57.71
# 83                 0.06   -7,264,596            -14,529.19
#
#     Year2 EPS - Net Income - Diluted  Year2 EPS from Continuing Operations  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ..                               ...                                   ...
# 79                             -0.40                                 -0.37
# 80                             -0.15                                 -0.15
# 81                             -5.58                                   NaN
# 82                             -0.20                                 -0.20
# 83                             -4.00                                 -4.00
#
#     Year2 Earnings per Share - Basic  Year2 Free Cash Flow per Share  \
# 0                                NaN                             NaN
# 1                                NaN                             NaN
# 2                                NaN                             NaN
# 3                                NaN                             NaN
# 4                                NaN                             NaN
# ..                               ...                             ...
# 79                             -0.40                           -0.05
# 80                             -0.15                           -0.12
# 81                             -5.58                            0.78
# 82                             -0.20                           -0.06
# 83                             -4.00                           -0.53
#
#     Year2 Gross Margin Year2 Long Term Debt Year2 Net Assets per Share  \
# 0                  NaN                  NaN                        NaN
# 1                  NaN                  NaN                        NaN
# 2                  NaN                  NaN                        NaN
# 3                  NaN                  NaN                        NaN
# 4                  NaN                  NaN                        NaN
# ..                 ...                  ...                        ...
# 79               95.23            1,238,000                       -0.6
# 80                 NaN            1,978,683                       0.12
# 81                1.15          225,000,000                       1.75
# 82              -13.35                  NaN                      -0.02
# 83              -28.00                  NaN                       -1.7
#
#    Year2 Net Current Assets as % of Total Assets Year2 Net Income  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
# 3                                            NaN              NaN
# 4                                            NaN              NaN
# ..                                           ...              ...
# 79                                        -64.76      -12,061,000
# 80                                        -28.63       -2,771,894
# 81                                         -0.66      -36,188,000
# 82                                        -70.56         -385,097
# 83                                       -728.86       -9,153,310
#
#    Year2 Operating Income Year2 Operating Margin  Year2 Price/Book (TTM)  \
# 0                     NaN                    NaN                     NaN
# 1                     NaN                    NaN                     NaN
# 2                     NaN                    NaN                     NaN
# 3                     NaN                    NaN                     NaN
# 4                     NaN                    NaN                     NaN
# ..                    ...                    ...                     ...
# 79             -8,739,000              -1,262.86                     NaN
# 80             -2,437,696              -6,094.24                   16.11
# 81             -7,715,000                 -14.14                     NaN
# 82               -383,991                 -58.37                     NaN
# 83             -1,729,983              -3,459.97                     NaN
#
#     Year2 Price/Cash Flow(TTM)  Year2 Price/Earnings (TTM)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 79                         NaN                         NaN
# 80                         NaN                         NaN
# 81                         NaN                         NaN
# 82                         NaN                         NaN
# 83                         NaN                         NaN
#
#    Year2 Profit Margin (TTM)  Year2 Quick Ratio Year2 Revenue per Share  \
# 0                        NaN                NaN                     NaN
# 1                        NaN                NaN                     NaN
# 2                        NaN                NaN                     NaN
# 3                        NaN                NaN                     NaN
# 4                        NaN                NaN                     NaN
# ..                       ...                ...                     ...
# 79                 -1,742.92                NaN                    0.02
# 80                 -6,929.74                NaN                       0
# 81                    -66.32                0.6                    4.24
# 82                    -58.54                NaN                    0.35
# 83                -18,306.62                NaN                    0.02
#
#     Year2 Revenue to Assets Year2 Share Outstanding  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 79                     0.02              32,749,920
# 80                     0.01              19,366,000
# 81                     0.21              13,930,137
# 82                    13.02            1,886,574.75
# 83                     0.05            3,618,401.74
#
#    Year2 Stockholders' Equity Year2 Total Assets Year2 Total Assets per Share  \
# 0                         NaN                NaN                          NaN
# 1                         NaN                NaN                          NaN
# 2                         NaN                NaN                          NaN
# 3                         NaN                NaN                          NaN
# 4                         NaN                NaN                          NaN
# ..                        ...                ...                          ...
# 79                -19,615,000         38,152,000                         1.16
# 80                  2,284,300          6,063,558                         0.31
# 81                          0        254,371,000                        18.26
# 82                    -35,643             50,515                         0.03
# 83                 -6,162,464            915,491                         0.25
#
#    Year2 Total Liabilities Year2 Total Revenue  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ..                     ...                 ...
# 79              57,767,000             692,000
# 80               3,779,258              40,000
# 81             229,953,000          54,564,000
# 82                  86,158             657,839
# 83               7,077,944              50,000
#
#    Year2 Weighted Average Shares Outstanding - Basic  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 79                                        32,118,000
# 80                                        19,007,371
# 81                                        12,859,607
# 82                                      1,886,574.75
# 83                                      2,683,254.20
#
#    Year2 Weighted Average Shares Outstanding - Diluted  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                         32,118,000
# 80                                         19,007,371
# 81                                         12,859,607
# 82                                       1,886,574.75
# 83                                       2,683,254.20
#
#    Year3 Calculated Tax Rate % Year3 Capital Expenditures  \
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN
# ..                         ...                        ...
# 79                       EBT<0                  2,789,000
# 80                       EBT<0                        NaN
# 81                         NaN                     55,000
# 82                       EBT<0                        NaN
# 83                       EBT<0                     20,757
#
#    Year3 Cash & Cash Equivalents, Beginning of Year  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# ..                                              ...
# 79                                          521,000
# 80                                          201,353
# 81                                        2,798,000
# 82                                           32,745
# 83                                           11,548
#
#    Year3 Cash & Cash Equivalents, End of Year  Year3 Cash Flow per Share  \
# 0                                         NaN                        NaN
# 1                                         NaN                        NaN
# 2                                         NaN                        NaN
# 3                                         NaN                        NaN
# 4                                         NaN                        NaN
# ..                                        ...                        ...
# 79                                    150,000                      -0.10
# 80                                         24                      -0.03
# 81                                  3,168,000                       2.25
# 82                                    114,508                       0.05
# 83                                     67,260                      -0.27
#
#    Year3 Cash from Financing Year3 Cash from Investing  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ..                       ...                       ...
# 79                 5,838,000                -3,480,000
# 80                   972,044                  -632,510
# 81               -26,243,000                -2,258,000
# 82                   -13,909                       NaN
# 83                   521,731                   -20,757
#
#    Year3 Cash from Operations Year3 Current Assets Year3 Current Liabilities  \
# 0                         NaN                  NaN                       NaN
# 1                         NaN                  NaN                       NaN
# 2                         NaN                  NaN                       NaN
# 3                         NaN                  NaN                       NaN
# 4                         NaN                  NaN                       NaN
# ..                        ...                  ...                       ...
# 79                 -2,729,000            3,180,000                19,714,000
# 80                   -540,863              261,649                 1,737,053
# 81                 28,871,000           10,078,000                 8,087,000
# 82                     95,909              869,882                   228,716
# 83                   -445,260              117,029                 2,790,747
#
#     Year3 Current Ratio Year3 EBITDA Year3 EBITDA Margin %  \
# 0                   NaN          NaN                   NaN
# 1                   NaN          NaN                   NaN
# 2                   NaN          NaN                   NaN
# 3                   NaN          NaN                   NaN
# 4                   NaN          NaN                   NaN
# ..                  ...          ...                   ...
# 79                 0.16   -3,076,000             -1,130.88
# 80                 0.15   -2,106,404             -3,510.67
# 81                 1.25   47,580,000                 62.93
# 82                 3.80      -40,250                 -3.15
# 83                 0.04   -2,232,302            -69,154.34
#
#     Year3 EPS - Net Income - Diluted  Year3 EPS from Continuing Operations  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
# 2                                NaN                                   NaN
# 3                                NaN                                   NaN
# 4                                NaN                                   NaN
# ..                               ...                                   ...
# 79                             -0.38                                 -0.29
# 80                             -0.13                                 -0.13
# 81                             -0.31                                 -0.31
# 82                             -0.02                                 -0.02
# 83                             -2.00                                 -2.00
#
#     Year3 Earnings per Share - Basic Year3 Free Cash Flow per Share  \
# 0                                NaN                            NaN
# 1                                NaN                            NaN
# 2                                NaN                            NaN
# 3                                NaN                            NaN
# 4                                NaN                            NaN
# ..                               ...                            ...
# 79                             -0.38                           -0.2
# 80                             -0.13                          -0.03
# 81                             -0.62                           2.24
# 82                             -0.02                           0.05
# 83                             -2.00                          -0.28
#
#    Year3 Gross Margin Year3 Long Term Debt Year3 Net Assets per Share  \
# 0                 NaN                  NaN                        NaN
# 1                 NaN                  NaN                        NaN
# 2                 NaN                  NaN                        NaN
# 3                 NaN                  NaN                        NaN
# 4                 NaN                  NaN                        NaN
# ..                ...                  ...                        ...
# 79                100            4,758,000                       -0.3
# 80                NaN            2,024,297                       0.04
# 81              32.14          225,000,000                       5.22
# 82              13.33                  NaN                       0.32
# 83               2.08                  NaN                       -1.3
#
#    Year3 Net Current Assets as % of Total Assets Year3 Net Income  \
# 0                                            NaN              NaN
# 1                                            NaN              NaN
# 2                                            NaN              NaN
# 3                                            NaN              NaN
# 4                                            NaN              NaN
# ..                                           ...              ...
# 79                                        -34.61       -8,119,000
# 80                                        -33.76       -2,210,764
# 81                                          0.66       -4,080,000
# 82                                         73.14          -45,691
# 83                                     -1,377.25       -2,977,889
#
#    Year3 Operating Income Year3 Operating Margin  Year3 Price/Book (TTM)  \
# 0                     NaN                    NaN                     NaN
# 1                     NaN                    NaN                     NaN
# 2                     NaN                    NaN                     NaN
# 3                     NaN                    NaN                     NaN
# 4                     NaN                    NaN                     NaN
# ..                    ...                    ...                     ...
# 79             -3,605,000              -1,325.37                     NaN
# 80             -1,129,421              -1,882.37                   17.34
# 81             15,874,000                  20.99                     NaN
# 82                -45,713                  -3.58                    0.17
# 83               -607,854             -18,830.67                     NaN
#
#     Year3 Price/Cash Flow(TTM)  Year3 Price/Earnings (TTM)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
# ..                         ...                         ...
# 79                         NaN                         NaN
# 80                         NaN                         NaN
# 81                         NaN                         NaN
# 82                        1.02                         NaN
# 83                         NaN                         NaN
#
#    Year3 Profit Margin (TTM)  Year3 Quick Ratio Year3 Revenue per Share  \
# 0                        NaN                NaN                     NaN
# 1                        NaN                NaN                     NaN
# 2                        NaN                NaN                     NaN
# 3                        NaN                NaN                     NaN
# 4                        NaN                NaN                     NaN
# ..                       ...                ...                     ...
# 79                 -2,984.93                NaN                    0.01
# 80                 -3,684.61                NaN                       0
# 81                      -5.4               1.24                    5.86
# 82                     -3.58                NaN                    0.68
# 83                -92,251.83                NaN                       0
#
#     Year3 Revenue to Assets Year3 Share Outstanding  \
# 0                       NaN                     NaN
# 1                       NaN                     NaN
# 2                       NaN                     NaN
# 3                       NaN                     NaN
# 4                       NaN                     NaN
# ..                      ...                     ...
# 79                     0.01              30,452,075
# 80                     0.01              17,031,000
# 81                     0.25              12,859,607
# 82                     1.46            2,036,574.75
# 83                     0.02            2,004,337.25
#
#    Year3 Stockholders' Equity Year3 Total Assets Year3 Total Assets per Share  \
# 0                         NaN                NaN                          NaN
# 1                         NaN                NaN                          NaN
# 2                         NaN                NaN                          NaN
# 3                         NaN                NaN                          NaN
# 4                         NaN                NaN                          NaN
# ..                        ...                ...                          ...
# 79                 -9,071,000         47,767,000                         1.57
# 80                    609,016          4,370,366                         0.26
# 81                          0        300,867,000                         23.4
# 82                    647,968            876,684                         0.43
# 83                 -2,596,613            194,134                          0.1
#
#    Year3 Total Liabilities Year3 Total Revenue  \
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ..                     ...                 ...
# 79              56,838,000             272,000
# 80               3,761,350              60,000
# 81             233,765,000          75,612,000
# 82                 228,716           1,276,883
# 83               2,790,747               3,228
#
#    Year3 Weighted Average Shares Outstanding - Basic  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ..                                               ...
# 79                                        28,147,000
# 80                                        17,031,000
# 81                                        12,859,607
# 82                                      1,871,917.20
# 83                                      1,673,862.73
#
#    Year3 Weighted Average Shares Outstanding - Diluted
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                         28,147,000
# 80                                         17,031,000
# 81                                         12,859,607
# 82                                       1,871,917.20
# 83                                       1,673,862.73
#
# [84 rows x 165 columns]

# %%
# %%time
list_of_dfs = [sic0,sic1,sic2,sic3,sic4,sic5,sic6,sic7,sic8,sic9]

data = pd.concat(list_of_dfs, ignore_index=True)
# write DataFrame to an excel sheet 
data.to_excel('/Users/peterflaming/Documents/GitHub/COMPS/Clean Data/appended.xlsx')

# %%
data.head()
# Out:
#                      Auditors                         Company Name  \
# 0                         NaN                        CORTEVA, INC.
# 1  PricewaterhouseCoopers LLP  CHIQUITA BRANDS INTERNATIONAL, INC.
# 2                         NaN                    THE ANDERSONS INC
# 3                         NaN            BRIGHTVIEW HOLDINGS, INC.
# 4           Ernst & Young LLP                CAL-MAINE FOODS, INC.
#
#   Company Type D-U-N-S@ Number Domestic Parent Duns No  \
# 0       Public     11-681-4324             11-681-4324
# 1       Public     05-154-1597             05-154-1597
# 2       Public     19-699-1731             19-699-1731
# 3       Public     07-941-1785             07-940-7937
# 4       Public     05-064-3436             05-064-3436
#
#         Domestic Parent Name Employee All Sites Employee this Site  \
# 0              CORTEVA, INC.             44,000                 28
# 1  CHIQUITA HOLDINGS LIMITED             20,000              1,000
# 2          THE ANDERSONS INC              1,858                150
# 3    BRIGHTVIEW PARENT, L.P.             19,000                 31
# 4      CAL-MAINE FOODS, INC.              3,573                422
#
#   Employees Total (Year 1)  Employer ID Number (EIN) Facility Size Fax No  \
# 0                   21,900               824979096.0             0    NaN
# 1                   20,000                41923360.0             0    NaN
# 2                    3,498               341562374.0       245,000    NaN
# 3                   19,000                       NaN             0    NaN
# 4                    3,573               640500378.0             0    NaN
#
#    Former Name Global Duns No                Global Name  \
# 0          NaN    11-681-4324              CORTEVA, INC.
# 1          NaN    22-031-2707  CHIQUITA HOLDINGS LIMITED
# 2          NaN    19-699-1731          THE ANDERSONS INC
# 3          NaN    07-940-7937    BRIGHTVIEW PARENT, L.P.
# 4          NaN    05-064-3436      CAL-MAINE FOODS, INC.
#
#   Immediate Parent Duns No      Immediate Parent Name Import/Export  \
# 0              11-681-4324              CORTEVA, INC.           NaN
# 1              22-031-2707  CHIQUITA HOLDINGS LIMITED          Both
# 2              19-699-1731          THE ANDERSONS INC           NaN
# 3              07-940-7937    BRIGHTVIEW PARENT, L.P.           NaN
# 4              05-064-3436      CAL-MAINE FOODS, INC.           NaN
#
#     Latitude                           Line of Business Location Type  \
# 0  39.752410          CROP PLANTING AND PROTECTION, NSK  Headquarters
# 1  26.062705             FRUITS AND TREE NUTS, NEC, NSK  Headquarters
# 2  41.582325  CROP PREPARATION SERVICES FOR MARKET, NSK  Headquarters
# 3  40.147526     LANDSCAPE COUNSELING AND PLANNING, NSK  Headquarters
# 4  32.325416                          CHICKEN EGGS, NSK  Headquarters
#
#    Longtitude Mailing Address Mailing City Mailing Country Mailing County  \
# 0  -75.609399             NaN          NaN             NaN            NaN
# 1  -80.161274             NaN          NaN             NaN            NaN
# 2  -83.696756    P.O. BOX 119       MAUMEE             USA          LUCAS
# 3  -75.288898             NaN          NaN             NaN            NaN
# 4  -90.223854   P.O. BOX 2960      JACKSON             USA          HINDS
#
#   Mailing State  Mailing Zipcode Manufacturing Indicator  \
# 0           NaN              NaN        Non Manufacturer
# 1           NaN              NaN        Non Manufacturer
# 2          OHIO      435370119.0        Non Manufacturer
# 3           NaN              NaN            Manufacturer
# 4   MISSISSIPPI      392072960.0            Manufacturer
#
#   Marketing Prescreen Ranking Marketing Prescreen Score  \
# 0      1 - Most likely to pay                       Low
# 1     5 - Least Likely to pay                      High
# 2           2 - Likely to pay                       Low
# 3      1 - Most likely to pay                       Low
# 4      4 - Less likely to pay                       Low
#
#   Minority Owned Indicator Owns/Rents        Phone No  \
# 0                       No        NaN  (302) 485-3000
# 1                       No       Rent  (954) 924-5700
# 2                       No       Rent  (419) 893-5050
# 3                       No       Rent  (484) 567-7204
# 4                       No        NaN  (601) 948-6813
#
#             Physical Address Physical City Physical Country Physical County  \
# 0     974 CENTRE RD BLDG 735    WILMINGTON              USA      NEW CASTLE
# 1   1855 GRIFFIN RD STE C436         DANIA              USA         BROWARD
# 2       1947 BRIARFIELD BLVD        MAUMEE              USA           LUCAS
# 3       980 JOLLY RD STE 300     BLUE BELL              USA      MONTGOMERY
# 4  3320 W WOODROW WILSON AVE       JACKSON              USA           HINDS
#
#   Physical State  Physical Zipcode  Primary SIC Code  \
# 0       DELAWARE       198051269.0         7210300.0
# 1        FLORIDA       330042275.0         1799902.0
# 2           OHIO       435371690.0         7230000.0
# 3   PENNSYLVANIA       194221904.0         7810200.0
# 4    MISSISSIPPI       392093409.0         2520000.0
#
#                   Rank Type            Sales  Sales (Year 1)  \
# 0                       NaN  $30,671,050,478  $3,125,084,910
# 1                       NaN   $3,399,246,400  $3,090,224,000
# 2                       NaN   $3,045,382,000  $3,045,382,000
# 3                       NaN   $2,353,603,000  $2,353,603,000
# 4  Russell 2000 (June 2016)   $1,361,188,000  $1,502,932,000
#
#   Subsidiary Status          Trade Style      Web Address (URL)  \
# 0    Non-Subsidiary  CORTEVA AGRISCIENCE        WWW.CORTEVA.COM
# 1        Subsidiary             CHIQUITA       WWW.CHIQUITA.COM
# 2    Non-Subsidiary                  NaN   WWW.ANDERSONSINC.COM
# 3        Subsidiary                  NaN     WWW.BRIGHTVIEW.COM
# 4    Non-Subsidiary                  NaN  WWW.CALMAINEFOODS.COM
#
#    Year of Founding Year1 Calculated Tax Rate % Year1 Capital Expenditures  \
# 0            2018.0                         NaN                        NaN
# 1            1899.0                         NaN                        NaN
# 2            1947.0                         NaN                        NaN
# 3            2013.0                         NaN                        NaN
# 4            1957.0                         NaN                        NaN
#
#   Year1 Cash & Cash Equivalents, Beginning of Year  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Year1 Cash & Cash Equivalents, End of Year Year1 Cash Flow per Share  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
# 3                                        NaN                       NaN
# 4                                        NaN                       NaN
#
#   Year1 Cash from Financing Year1 Cash from Investing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   Year1 Cash from Operations Year1 Current Assets Year1 Current Liabilities  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        NaN                  NaN                       NaN
# 4                        NaN                  NaN                       NaN
#
#   Year1 Current Ratio Year1 EBITDA Year1 EBITDA Margin %  \
# 0                 NaN          NaN                   NaN
# 1                 NaN          NaN                   NaN
# 2                 NaN          NaN                   NaN
# 3                 NaN          NaN                   NaN
# 4                 NaN          NaN                   NaN
#
#   Year1 EPS - Net Income - Diluted Year1 EPS from Continuing Operations  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   Year1 Earnings per Share - Basic Year1 Free Cash Flow per Share  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#   Year1 Gross Margin Year1 Long Term Debt Year1 Net Assets per Share  \
# 0                NaN                  NaN                        NaN
# 1                NaN                  NaN                        NaN
# 2                NaN                  NaN                        NaN
# 3                NaN                  NaN                        NaN
# 4                NaN                  NaN                        NaN
#
#   Year1 Net Current Assets as % of Total Assets Year1 Net Income  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
#
#   Year1 Operating Income Year1 Operating Margin Year1 Price/Book (TTM)  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#   Year1 Price/Cash Flow(TTM) Year1 Price/Earnings (TTM)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   Year1 Profit Margin (TTM) Year1 Quick Ratio Year1 Revenue per Share  \
# 0                       NaN               NaN                     NaN
# 1                       NaN               NaN                     NaN
# 2                       NaN               NaN                     NaN
# 3                       NaN               NaN                     NaN
# 4                       NaN               NaN                     NaN
#
#   Year1 Revenue to Assets Year1 Share Outstanding Year1 Stockholders' Equity  \
# 0                     NaN                     NaN                        NaN
# 1                     NaN                     NaN                        NaN
# 2                     NaN                     NaN                        NaN
# 3                     NaN                     NaN                        NaN
# 4                     NaN                     NaN                        NaN
#
#   Year1 Total Assets Year1 Total Assets per Share Year1 Total Liabilities  \
# 0                NaN                          NaN                     NaN
# 1                NaN                          NaN                     NaN
# 2                NaN                          NaN                     NaN
# 3                NaN                          NaN                     NaN
# 4                NaN                          NaN                     NaN
#
#   Year1 Total Revenue Year1 Weighted Average Shares Outstanding - Basic  \
# 0                 NaN                                               NaN
# 1                 NaN                                               NaN
# 2                 NaN                                               NaN
# 3                 NaN                                               NaN
# 4                 NaN                                               NaN
#
#   Year1 Weighted Average Shares Outstanding - Diluted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Year2 Calculated Tax Rate % Year2 Capital Expenditures  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   Year2 Cash & Cash Equivalents, Beginning of Year  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Year2 Cash & Cash Equivalents, End of Year Year2 Cash Flow per Share  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
# 3                                        NaN                       NaN
# 4                                        NaN                       NaN
#
#   Year2 Cash from Financing Year2 Cash from Investing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   Year2 Cash from Operations Year2 Current Assets Year2 Current Liabilities  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        NaN                  NaN                       NaN
# 4                        NaN                  NaN                       NaN
#
#   Year2 Current Ratio Year2 EBITDA Year2 EBITDA Margin %  \
# 0                 NaN          NaN                   NaN
# 1                 NaN          NaN                   NaN
# 2                 NaN          NaN                   NaN
# 3                 NaN          NaN                   NaN
# 4                 NaN          NaN                   NaN
#
#   Year2 EPS - Net Income - Diluted Year2 EPS from Continuing Operations  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   Year2 Earnings per Share - Basic Year2 Free Cash Flow per Share  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#   Year2 Gross Margin Year2 Long Term Debt Year2 Net Assets per Share  \
# 0                NaN                  NaN                        NaN
# 1                NaN                  NaN                        NaN
# 2                NaN                  NaN                        NaN
# 3                NaN                  NaN                        NaN
# 4                NaN                  NaN                        NaN
#
#   Year2 Net Current Assets as % of Total Assets Year2 Net Income  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
#
#   Year2 Operating Income Year2 Operating Margin Year2 Price/Book (TTM)  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#   Year2 Price/Cash Flow(TTM) Year2 Price/Earnings (TTM)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   Year2 Profit Margin (TTM)  Year2 Quick Ratio Year2 Revenue per Share  \
# 0                       NaN                NaN                     NaN
# 1                       NaN                NaN                     NaN
# 2                       NaN                NaN                     NaN
# 3                       NaN                NaN                     NaN
# 4                       NaN                NaN                     NaN
#
#   Year2 Revenue to Assets Year2 Share Outstanding Year2 Stockholders' Equity  \
# 0                     NaN                     NaN                        NaN
# 1                     NaN                     NaN                        NaN
# 2                     NaN                     NaN                        NaN
# 3                     NaN                     NaN                        NaN
# 4                     NaN                     NaN                        NaN
#
#   Year2 Total Assets Year2 Total Assets per Share Year2 Total Liabilities  \
# 0                NaN                          NaN                     NaN
# 1                NaN                          NaN                     NaN
# 2                NaN                          NaN                     NaN
# 3                NaN                          NaN                     NaN
# 4                NaN                          NaN                     NaN
#
#   Year2 Total Revenue Year2 Weighted Average Shares Outstanding - Basic  \
# 0                 NaN                                               NaN
# 1                 NaN                                               NaN
# 2                 NaN                                               NaN
# 3                 NaN                                               NaN
# 4                 NaN                                               NaN
#
#   Year2 Weighted Average Shares Outstanding - Diluted  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Year3 Calculated Tax Rate % Year3 Capital Expenditures  \
# 0                         NaN                        NaN
# 1                         NaN                        NaN
# 2                         NaN                        NaN
# 3                         NaN                        NaN
# 4                         NaN                        NaN
#
#   Year3 Cash & Cash Equivalents, Beginning of Year  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Year3 Cash & Cash Equivalents, End of Year Year3 Cash Flow per Share  \
# 0                                        NaN                       NaN
# 1                                        NaN                       NaN
# 2                                        NaN                       NaN
# 3                                        NaN                       NaN
# 4                                        NaN                       NaN
#
#   Year3 Cash from Financing Year3 Cash from Investing  \
# 0                       NaN                       NaN
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#   Year3 Cash from Operations Year3 Current Assets Year3 Current Liabilities  \
# 0                        NaN                  NaN                       NaN
# 1                        NaN                  NaN                       NaN
# 2                        NaN                  NaN                       NaN
# 3                        NaN                  NaN                       NaN
# 4                        NaN                  NaN                       NaN
#
#   Year3 Current Ratio Year3 EBITDA Year3 EBITDA Margin %  \
# 0                 NaN          NaN                   NaN
# 1                 NaN          NaN                   NaN
# 2                 NaN          NaN                   NaN
# 3                 NaN          NaN                   NaN
# 4                 NaN          NaN                   NaN
#
#   Year3 EPS - Net Income - Diluted Year3 EPS from Continuing Operations  \
# 0                              NaN                                  NaN
# 1                              NaN                                  NaN
# 2                              NaN                                  NaN
# 3                              NaN                                  NaN
# 4                              NaN                                  NaN
#
#   Year3 Earnings per Share - Basic Year3 Free Cash Flow per Share  \
# 0                              NaN                            NaN
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
#
#   Year3 Gross Margin Year3 Long Term Debt Year3 Net Assets per Share  \
# 0                NaN                  NaN                        NaN
# 1                NaN                  NaN                        NaN
# 2                NaN                  NaN                        NaN
# 3                NaN                  NaN                        NaN
# 4                NaN                  NaN                        NaN
#
#   Year3 Net Current Assets as % of Total Assets Year3 Net Income  \
# 0                                           NaN              NaN
# 1                                           NaN              NaN
# 2                                           NaN              NaN
# 3                                           NaN              NaN
# 4                                           NaN              NaN
#
#   Year3 Operating Income Year3 Operating Margin Year3 Price/Book (TTM)  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#   Year3 Price/Cash Flow(TTM) Year3 Price/Earnings (TTM)  \
# 0                        NaN                        NaN
# 1                        NaN                        NaN
# 2                        NaN                        NaN
# 3                        NaN                        NaN
# 4                        NaN                        NaN
#
#   Year3 Profit Margin (TTM) Year3 Quick Ratio Year3 Revenue per Share  \
# 0                       NaN               NaN                     NaN
# 1                       NaN               NaN                     NaN
# 2                       NaN               NaN                     NaN
# 3                       NaN               NaN                     NaN
# 4                       NaN               NaN                     NaN
#
#   Year3 Revenue to Assets Year3 Share Outstanding Year3 Stockholders' Equity  \
# 0                     NaN                     NaN                        NaN
# 1                     NaN                     NaN                        NaN
# 2                     NaN                     NaN                        NaN
# 3                     NaN                     NaN                        NaN
# 4                     NaN                     NaN                        NaN
#
#   Year3 Total Assets Year3 Total Assets per Share Year3 Total Liabilities  \
# 0                NaN                          NaN                     NaN
# 1                NaN                          NaN                     NaN
# 2                NaN                          NaN                     NaN
# 3                NaN                          NaN                     NaN
# 4                NaN                          NaN                     NaN
#
#   Year3 Total Revenue Year3 Weighted Average Shares Outstanding - Basic  \
# 0                 NaN                                               NaN
# 1                 NaN                                               NaN
# 2                 NaN                                               NaN
# 3                 NaN                                               NaN
# 4                 NaN                                               NaN
#
#   Year3 Weighted Average Shares Outstanding - Diluted
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23426 entries, 0 to 23425
# Columns: 165 entries, Auditors to Year3 Weighted Average Shares Outstanding - Diluted
# dtypes: float64(9), object(156)
# memory usage: 29.5+ MB

# %%
data.dtypes
# Out:
# Auditors                                               object
# Company Name                                           object
# Company Type                                           object
# D-U-N-S@ Number                                        object
# Domestic Parent Duns No                                object
#                                                         ...
# Year3 Total Assets per Share                           object
# Year3 Total Liabilities                                object
# Year3 Total Revenue                                    object
# Year3 Weighted Average Shares Outstanding - Basic      object
# Year3 Weighted Average Shares Outstanding - Diluted    object
# Length: 165, dtype: object

# %%
def cleanup_text(text): 
    exps = ['[{](["].+["][:].+)+[}]',
            '\\\n','-', ',', '[<]\s*\w+\s*/[>]',
            'window[.][_]msla[=].*;',
            'function[(]\s*[)]\s*{.*}']

    for e in exps:
        text = re.sub(e, '', text)
    return text

# %%
data.dtypes
# Out:
# Auditors                                                 object
# Company Name                                           category
# Company Type                                             object
# D-U-N-S@ Number                                          object
# Domestic Parent Duns No                                  object
#                                                          ...
# Year3 Total Assets per Share                             object
# Year3 Total Liabilities                                  object
# Year3 Total Revenue                                      object
# Year3 Weighted Average Shares Outstanding - Basic        object
# Year3 Weighted Average Shares Outstanding - Diluted      object
# Length: 165, dtype: object

# %%
data['Company Name'] = data['Company Name'].astype('category')
data['Company Type'] = data['Company Type'].astype('category')
data['Import/Export'] = data['Import/Export'].astype('category')
data['Global Name'] = data['Global Name'].astype('category')
data['Immediate Parent Name'] = data['Immediate Parent Name'].astype('category')
data['Line of Business'] = data['Line of Business'].astype('category')
data['Manufacturing Indicator'] = data['Manufacturing Indicator'].astype('category')
data['Marketing Prescreen Score'] = data['Marketing Prescreen Score'].astype('category')
data['Marketing Prescreen Ranking'] = data['Marketing Prescreen Ranking'].astype('category')
data['Minority Owned Indicator'] = data['Minority Owned Indicator'].astype('category')
data['Global Name'] = data['Global Name'].astype('category')
data['Owns/Rents'] = data['Owns/Rents'].astype('category')
data['Subsidiary Status'] = data['Subsidiary Status'].astype('category')
data['Web Address (URL)'] = data['Web Address (URL)'].astype('category')

# %%
# data['Company Name'] = data['Company Name'].astype('category')
# data[data.select_dtypes(['object']).columns] = data.select_dtypes(['object']).apply(lambda x: x.apply(cleanup_text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-38a386fab02f> in <module>
#       1 data['Company Name'] = data['Company Name'].astype('category')
# ----> 2 data[data.select_dtypes(['object']).columns] = data.select_dtypes(['object']).apply(lambda x: x.apply(cleanup_text))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-41-38a386fab02f> in <lambda>(x)
#       1 data['Company Name'] = data['Company Name'].astype('category')
# ----> 2 data[data.select_dtypes(['object']).columns] = data.select_dtypes(['object']).apply(lambda x: x.apply(cleanup_text))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-c85c5d37a7d9> in cleanup_text(text)
#       6
#       7     for e in exps:
# ----> 8         text = re.sub(e, '', text)
#       9     return text
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: ('expected string or bytes-like object', 'occurred at index Auditors')

# %%
data = data.apply(lambda x: x.apply(cleanup_text))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-63d6cc4cfec1> in <module>
# ----> 1 data = data.apply(lambda x: x.apply(cleanup_text))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6926             kwds=kwds,
#    6927         )
# -> 6928         return op.get_result()
#    6929
#    6930     def applymap(self, func):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in get_result(self)
#     184             return self.apply_raw()
#     185
# --> 186         return self.apply_standard()
#     187
#     188     def apply_empty_result(self):
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     290
#     291         # compute the result using the series generator
# --> 292         self.apply_series_generator()
#     293
#     294         # wrap results
#
# /usr/local/lib/python3.7/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     319             try:
#     320                 for i, v in enumerate(series_gen):
# --> 321                     results[i] = self.f(v)
#     322                     keys.append(v.name)
#     323             except Exception as e:
#
# <ipython-input-43-63d6cc4cfec1> in <lambda>(x)
# ----> 1 data = data.apply(lambda x: x.apply(cleanup_text))
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4043             else:
#    4044                 values = self.astype(object).values
# -> 4045                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4046
#    4047         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-c85c5d37a7d9> in cleanup_text(text)
#       6
#       7     for e in exps:
# ----> 8         text = re.sub(e, '', text)
#       9     return text
#
# /usr/local/Cellar/python/3.7.5/Frameworks/Python.framework/Versions/3.7/lib/python3.7/re.py in sub(pattern, repl, string, count, flags)
#     190     a callable, it's passed the Match object and must return
#     191     a replacement string to be used."""
# --> 192     return _compile(pattern, flags).sub(repl, string, count)
#     193
#     194 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: ('expected string or bytes-like object', 'occurred at index Auditors')

# %%
data.shape
# Out:
# (23426, 165)

# %%
data['Company Name'].value_counts().head(90)
# Out:
# PHI GROUP, INC.                         4
# SAFECO INSURANCE COMPANY OF ILLINOIS    4
# HIGHLANDS BANKSHARES, INC.              4
# FEDERATED INVESTORS, INC.               4
# DYNCORP INTERNATIONAL LLC               4
#                                        ..
# FOCUS ENHANCEMENTS, INC.                2
# FORTUNE BRANDS HOME & SECURITY, INC.    2
# FORUM MERGER II CORPORATION             2
# FOG CUTTER CAPITAL GROUP INC.           2
# FORTUNE INDUSTRIES, INC.                2
# Name: Company Name, Length: 90, dtype: int64

# %%
data.describe()
# Out:
#        Employer ID Number (EIN)  Former Name      Latitude    Longtitude  \
# count              7.943000e+03          0.0  11391.000000  11391.000000
# mean               4.965970e+08          NaN     37.578912    -91.994537
# std                2.989202e+08          NaN      5.250524     18.193897
# min                1.002437e+07          NaN      0.000000   -157.929700
# 25%                2.224109e+08          NaN     33.901239   -106.633259
# 50%                4.503112e+08          NaN     39.077412    -87.624146
# 75%                7.700399e+08          NaN     40.975186    -75.700245
# max                9.980655e+08          NaN     64.842461      0.000000
#
#        Mailing Zipcode  Physical Zipcode  Primary SIC Code  Year of Founding  \
# count     1.315000e+03      1.139100e+04      1.139100e+04      11382.000000
# mean      4.905980e+08      4.806486e+08      5.243484e+07       1907.007380
# std       2.835602e+08      3.399904e+08      2.097569e+07        389.942585
# min       2.199000e+03      6.460000e+02      1.160000e+06          0.000000
# 25%       2.684156e+08      1.178943e+08      3.621011e+07       1978.000000
# 50%       4.727410e+08      4.584024e+08      5.812031e+07       1995.000000
# 75%       7.526602e+08      8.020262e+08      6.798000e+07       2006.000000
# max       9.970739e+08      9.970174e+08      9.999222e+07       2019.000000
#
#        Year2 Quick Ratio
# count        5837.000000
# mean            2.715765
# std            13.369296
# min             0.000000
# 25%             0.580000
# 50%             1.110000
# 75%             2.090000
# max           760.360000

# %%
missing = data.isna().sum()
missing
# Out:
# Auditors                                               18392
# Company Name                                            2048
# Company Type                                           12035
# D-U-N-S@ Number                                         2048
# Domestic Parent Duns No                                15182
#                                                        ...
# Year3 Total Assets per Share                           14223
# Year3 Total Liabilities                                13945
# Year3 Total Revenue                                    14808
# Year3 Weighted Average Shares Outstanding - Basic      14921
# Year3 Weighted Average Shares Outstanding - Diluted    14922
# Length: 165, dtype: int64

# %%
sns.countplot(missing)

# %%
data.hist(figsize=(20,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13287c6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1ace6ccd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x19bf82f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x20832f750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x133de6a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x132618d50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x13263db90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x13265cf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1326640d0>]],
#       dtype=object)

# %%
# https://towardsdatascience.com/a-starter-pack-to-exploratory-data-analysis-with-python-pandas-seaborn-and-scikit-learn-a77889485baf

c_palette = ['tab:blue', 'tab:orange']

def quantitative_summarized(dataframe, x=None, y=None, hue=None, palette='Set1', ax=None, verbose=True, swarm=False):
    '''
    Helper function that gives a quick summary of quantattive data
    Arguments
    =========
    dataframe: pandas dataframe
    x: str. horizontal axis to plot the labels of categorical data (usually the target variable)
    y: str. vertical axis to plot the quantitative data
    hue: str. if you want to compare it another categorical variable (usually the target variable if x is another variable)
    palette: array-like. Colour of the plot
    swarm: if swarm is set to True, a swarm plot would be overlayed
    Returns
    =======
    Quick Stats of the data and also the box plot of the distribution
    '''
    series = dataframe[y]
    print(series.describe())
    print('mode: ', series.mode())
    if verbose:
        print('='*80)
        print(series.value_counts())

    sns.boxplot(x=x, y=y, hue=hue, data=dataframe, palette=palette, ax=ax)

    if swarm:
        sns.swarmplot(x=x, y=y, hue=hue, data=dataframe,
                      palette=palette, ax=ax)

    plt.show()

# %%
# univariate analysis
quantitative_summarized(dataframe= data, palette=c_palette, verbose=False, swarm=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-2b0befb523f7> in <module>
#       1 # univariate analysis
# ----> 2 quantitative_summarized(dataframe= data, palette=c_palette, verbose=False, swarm=True)
#
# <ipython-input-37-92c304ec42fa> in quantitative_summarized(dataframe, x, y, hue, palette, ax, verbose, swarm)
#      18     Quick Stats of the data and also the box plot of the distribution
#      19     '''
# ---> 20     series = dataframe[y]
#      21     print(series.describe())
#      22     print('mode: ', series.mode())
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: None
